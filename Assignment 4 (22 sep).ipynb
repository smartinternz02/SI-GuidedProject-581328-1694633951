# %% [markdown]
# # Saptarshi Mukherjee  (21BAI10441)

# %% [markdown]
# # Assignment 4

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
pd.set_option("display.max_columns", None)
pd.set_option('display.max_colwidth', 35)
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.head(3)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction Gender  HourlyRate  \
# 1465            2061                        3   Male          41
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# # Checking the null value

# %%
df.isnull().any()
# Out:
# Age                         False
# Attrition                   False
# BusinessTravel              False
# DailyRate                   False
# Department                  False
# DistanceFromHome            False
# Education                   False
# EducationField              False
# EmployeeCount               False
# EmployeeNumber              False
# EnvironmentSatisfaction     False
# Gender                      False
# HourlyRate                  False
# JobInvolvement              False
# JobLevel                    False
# JobRole                     False
# JobSatisfaction             False
# MaritalStatus               False
# MonthlyIncome               False
# MonthlyRate                 False
# NumCompaniesWorked          False
# Over18                      False
# OverTime                    False
# PercentSalaryHike           False
# PerformanceRating           False
# RelationshipSatisfaction    False
# StandardHours               False
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# ## Droping unnecessary features

# %%
df.drop(['EmployeeNumber','EmployeeCount','StandardHours','Over18'],axis=1,inplace=True)
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  HourlyRate  JobInvolvement  JobLevel                JobRole  \
# ...

# %% [markdown]
# ## Data Visualization

# %%
plt.subplots(figsize=(20,15))
corr_mat = df.corr()
sns.heatmap(corr_mat,annot=True)
# Out:
# C:\Users\Saptarshi Mukherjee\AppData\Local\Temp\ipykernel_20412\3200092999.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_mat = df.corr()
# <Axes: >

# %%
def correlation (dataset, threshold):
    col_corr=set()
    for i in range(len(corr_mat.columns)):
        for j in range(i):
            if (abs(corr_mat.iloc[i,j])>threshold):
                colname = corr_mat.columns[i]
                col_corr.add(colname)
    
    return col_corr

# %%
corr_features = correlation(df,0.9)
len(set(corr_features))
# Out:
# 1

# %%
corr_features
# Out:
# {'MonthlyIncome'}

# %% [markdown]
# monthly income is highly correlated to job level

# %%
df.drop(corr_features,axis=1)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# ...

# %%
def annotateCntPlt(ax):# Used for annotating count plot
    for label in ax.containers:
        ax.bar_label(label)
    plt.show()

# %%
dep = sns.countplot(data=df, x='Department', hue='Attrition')
annotateCntPlt(dep)

# %% [markdown]
# Attrition Percentage from each department-
# - Sales - 20.63%
# - Research & Development - 13.84%
# - Human Resources - 19.05%

# %%
trv = sns.countplot(data=df, x='BusinessTravel', hue='Attrition')
annotateCntPlt(trv)

# %%
dst = sns.countplot(data=df, x='DistanceFromHome', hue='Attrition')
annotateCntPlt(dst)

# %%
est = sns.countplot(data=df, x='EnvironmentSatisfaction', hue='Attrition')
annotateCntPlt(est)

# %%
gdr = sns.countplot(data=df, x='Gender', hue='Attrition')
annotateCntPlt(gdr)

# %%
inv = sns.countplot(data=df, x='JobInvolvement', hue='Attrition')
annotateCntPlt(inv)

# %%
ms = sns.countplot(data=df, x='MaritalStatus', hue='Attrition')
annotateCntPlt(ms)

# %%
ncw = sns.countplot(data=df, x='NumCompaniesWorked', hue='Attrition')
annotateCntPlt(ncw)

# %%
psh = sns.countplot(data=df, x='PercentSalaryHike', hue='Attrition')
annotateCntPlt(psh)

# %%
ot = sns.countplot(data=df, x='OverTime', hue='Attrition')
annotateCntPlt(ot)

# %%
wlb = sns.countplot(data=df, x='WorkLifeBalance', hue='Attrition')
annotateCntPlt(wlb)

# %% [markdown]
# ## Outlier detection

# %%
sns.boxplot(df.Age)#checking for outliers
# Out:
# <Axes: >

# %%
sns.boxplot(df.DailyRate)
# Out:
# <Axes: >

# %%
sns.boxplot(df.DistanceFromHome)
# Out:
# <Axes: >

# %%
sns.boxplot(df.HourlyRate)
# Out:
# <Axes: >

# %%
sns.boxplot(df.MonthlyIncome)
# Out:
# <Axes: >

# %%
upper_limit = df['MonthlyIncome'].mean() + 3* df['MonthlyIncome'].std() # Right from the mean
lower_limit = df['MonthlyIncome'].mean() - 3* df['MonthlyIncome'].std() # Left from the mean

quant=df['MonthlyIncome'].quantile(q=[0.75,0.25])

q3=quant.loc[0.75]

q1=quant.loc[0.25]

IQR=q3-q1

maxwhisker=q3+1.5*IQR

minwhisker=q1-1.5*IQR

df['MonthlyIncome']=np.where(df.MonthlyIncome>maxwhisker,maxwhisker,df.MonthlyIncome)

df['MonthlyIncome']=np.where(df.MonthlyIncome<minwhisker,minwhisker,df.MonthlyIncome)

# %%
sns.boxplot(df.MonthlyIncome)
# Out:
# <Axes: >

# %%
sns.boxplot(df.MonthlyRate)
# Out:
# <Axes: >

# %%
sns.boxplot(df.NumCompaniesWorked)
# Out:
# <Axes: >

# %%
upper_limit = df['NumCompaniesWorked'].mean() + 3* df['NumCompaniesWorked'].std() # Right from the mean
lower_limit = df['NumCompaniesWorked'].mean() - 3* df['NumCompaniesWorked'].std() # Left from the mean

quant=df['NumCompaniesWorked'].quantile(q=[0.75,0.25])

q3=quant.loc[0.75]

q1=quant.loc[0.25]

IQR=q3-q1

maxwhisker=q3+1.5*IQR

minwhisker=q1-1.5*IQR

df['NumCompaniesWorked']=np.where(df.NumCompaniesWorked>maxwhisker,maxwhisker,df.NumCompaniesWorked)

df['NumCompaniesWorked']=np.where(df.NumCompaniesWorked<minwhisker,minwhisker,df.NumCompaniesWorked)

# %%
sns.boxplot(df.NumCompaniesWorked)
# Out:
# <Axes: >

# %%
sns.boxplot(df.PercentSalaryHike)
# Out:
# <Axes: >

# %%
sns.boxplot(df.StockOptionLevel)
# Out:
# <Axes: >

# %%
upper_limit = df['StockOptionLevel'].mean() + 3* df['StockOptionLevel'].std() # Right from the mean
lower_limit = df['StockOptionLevel'].mean() - 3* df['StockOptionLevel'].std() # Left from the mean

quant=df['StockOptionLevel'].quantile(q=[0.75,0.25])

q3=quant.loc[0.75]

q1=quant.loc[0.25]

IQR=q3-q1

maxwhisker=q3+1.5*IQR

minwhisker=q1-1.5*IQR

df['StockOptionLevel']=np.where(df.StockOptionLevel>maxwhisker,maxwhisker,df.StockOptionLevel)

df['StockOptionLevel']=np.where(df.StockOptionLevel<minwhisker,minwhisker,df.StockOptionLevel)

# %%
sns.boxplot(df.StockOptionLevel)
# Out:
# <Axes: >

# %%
sns.boxplot(df.TrainingTimesLastYear)
# Out:
# <Axes: >

# %%
upper_limit = df['TrainingTimesLastYear'].mean() + 3* df['TrainingTimesLastYear'].std() # Right from the mean
lower_limit = df['TrainingTimesLastYear'].mean() - 3* df['TrainingTimesLastYear'].std() # Left from the mean

quant=df['TrainingTimesLastYear'].quantile(q=[0.75,0.25])

q3=quant.loc[0.75]

q1=quant.loc[0.25]

IQR=q3-q1

maxwhisker=q3+1.5*IQR

minwhisker=q1-1.5*IQR

df['TrainingTimesLastYear']=np.where(df.TrainingTimesLastYear>maxwhisker,maxwhisker,df.TrainingTimesLastYear)

df['TrainingTimesLastYear']=np.where(df.TrainingTimesLastYear<minwhisker,minwhisker,df.TrainingTimesLastYear)

# %%
sns.boxplot(df.TrainingTimesLastYear)
# Out:
# <Axes: >

# %%
sns.boxplot(df.WorkLifeBalance)
# Out:
# <Axes: >

# %%
sns.boxplot(df.YearsAtCompany)
# Out:
# <Axes: >

# %%
upper_limit = df['YearsAtCompany'].mean() + 3* df['YearsAtCompany'].std() # Right from the mean
lower_limit = df['YearsAtCompany'].mean() - 3* df['YearsAtCompany'].std() # Left from the mean

quant=df['YearsAtCompany'].quantile(q=[0.75,0.25])

q3=quant.loc[0.75]

q1=quant.loc[0.25]

IQR=q3-q1

maxwhisker=q3+1.5*IQR

minwhisker=q1-1.5*IQR

df['YearsAtCompany']=np.where(df.YearsAtCompany>maxwhisker,maxwhisker,df.YearsAtCompany)

df['YearsAtCompany']=np.where(df.YearsAtCompany<minwhisker,minwhisker,df.YearsAtCompany)

# %%
sns.boxplot(df.YearsAtCompany)
# Out:
# <Axes: >

# %%
sns.boxplot(df.YearsInCurrentRole)
# Out:
# <Axes: >

# %%
upper_limit = df['YearsInCurrentRole'].mean() + 3* df['YearsInCurrentRole'].std() # Right from the mean
lower_limit = df['YearsInCurrentRole'].mean() - 3* df['YearsInCurrentRole'].std() # Left from the mean

quant=df['YearsInCurrentRole'].quantile(q=[0.75,0.25])

q3=quant.loc[0.75]

q1=quant.loc[0.25]

IQR=q3-q1

maxwhisker=q3+1.5*IQR

minwhisker=q1-1.5*IQR

df['YearsInCurrentRole']=np.where(df.YearsInCurrentRole>maxwhisker,maxwhisker,df.YearsInCurrentRole)

df['YearsInCurrentRole']=np.where(df.YearsInCurrentRole<minwhisker,minwhisker,df.YearsInCurrentRole)

# %%
sns.boxplot(df.YearsInCurrentRole)
# Out:
# <Axes: >

# %%
sns.boxplot(df.YearsSinceLastPromotion)
# Out:
# <Axes: >

# %%
upper_limit = df['YearsSinceLastPromotion'].mean() + 3* df['YearsSinceLastPromotion'].std() # Right from the mean
lower_limit = df['YearsSinceLastPromotion'].mean() - 3* df['YearsSinceLastPromotion'].std() # Left from the mean

quant=df['YearsSinceLastPromotion'].quantile(q=[0.75,0.25])

q3=quant.loc[0.75]

q1=quant.loc[0.25]

IQR=q3-q1

maxwhisker=q3+1.5*IQR

minwhisker=q1-1.5*IQR

df['YearsSinceLastPromotion']=np.where(df.YearsSinceLastPromotion>maxwhisker,maxwhisker,df.YearsSinceLastPromotion)

df['YearsSinceLastPromotion']=np.where(df.YearsSinceLastPromotion<minwhisker,minwhisker,df.YearsSinceLastPromotion)

# %%
sns.boxplot(df.YearsSinceLastPromotion)
# Out:
# <Axes: >

# %%
sns.boxplot(df.YearsWithCurrManager)
# Out:
# <Axes: >

# %%
upper_limit = df['YearsWithCurrManager'].mean() + 3* df['YearsWithCurrManager'].std() # Right from the mean
lower_limit = df['YearsWithCurrManager'].mean() - 3* df['YearsWithCurrManager'].std() # Left from the mean

quant=df['YearsWithCurrManager'].quantile(q=[0.75,0.25])

q3=quant.loc[0.75]

q1=quant.loc[0.25]

IQR=q3-q1

maxwhisker=q3+1.5*IQR

minwhisker=q1-1.5*IQR

df['YearsWithCurrManager']=np.where(df.YearsWithCurrManager>maxwhisker,maxwhisker,df.YearsWithCurrManager)

df['YearsWithCurrManager']=np.where(df.YearsWithCurrManager<minwhisker,minwhisker,df.YearsWithCurrManager)

# %%
sns.boxplot(df.YearsWithCurrManager)
# Out:
# <Axes: >

# %% [markdown]
# ## Splitting Dependent and Independent Features

# %%
X=df.drop(columns=["Attrition"],axis=1)
y=df["Attrition"]

# %%
X.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  HourlyRate  JobInvolvement  JobLevel                JobRole  \
# 0  Female          94               3         2        Sales Executive
# ...

# %%
y.head()
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# 4     No
# Name: Attrition, dtype: object

# %% [markdown]
# ## Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
y=le.fit_transform(y)

# %%
y
# Out:
# array([1, 0, 1, ..., 0, 0, 0])

# %%
X['BusinessTravel']=le.fit_transform(X['BusinessTravel'])
X['EducationField']=le.fit_transform(X['EducationField'])
X['Department']=le.fit_transform(X['Department'])
X['Gender']=le.fit_transform(X['Gender'])
X['JobRole']=le.fit_transform(X['JobRole'])
X['MaritalStatus']=le.fit_transform(X['MaritalStatus'])
X['OverTime']=le.fit_transform(X['OverTime'])

# %%
X.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   41               2       1102           2                 1          2
# 1   49               1        279           1                 8          1
# 2   37               2       1373           1                 2          2
# 3   33               1       1392           1                 3          4
# 4   27               2        591           1                 2          1
#
#    EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0               1                        2       0          94
# 1               1                        3       1          61
# 2               4                        4       1          92
# 3               1                        4       0          56
# 4               3                        1       1          40
#
#    JobInvolvement  JobLevel  JobRole  JobSatisfaction  MaritalStatus  \
# ...

# %% [markdown]
# ## Splitting into training and testing datasets

# %%
from sklearn.model_selection  import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((1176, 30), (1176,), (294, 30), (294,))

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %%
X_train
# Out:
# array([[ 2.3389367 ,  0.595307  , -0.48557354, ..., -1.1720921 ,
#         -0.76830996, -1.16340535],
#        [ 0.9043263 ,  0.595307  ,  0.36465323, ..., -0.05008941,
#         -0.76830996, -0.30839148],
#        [ 0.35255307,  0.595307  , -1.23722329, ...,  0.79141261,
#          2.06217899,  0.26161776],
#        ...,
#        [ 0.68361701,  0.595307  ,  0.92900666, ...,  1.35241396,
#          2.26435678,  1.11663163],
#        [ 0.13184377,  0.595307  , -1.31608491, ..., -1.1720921 ,
#         -0.76830996, -0.87840072],
#        [ 0.35255307,  0.595307  , -0.35495899, ..., -1.1720921 ,
#         -0.76830996, -1.16340535]])

# %%
X_test
# Out:
# array([[-0.14880903, -2.62109326, -0.43010976, ..., -0.37769898,
#          2.201189  ,  0.78734164],
#        [-0.46815103,  0.56980288, -0.58254453, ..., -0.37769898,
#         -0.80787594, -0.62325216],
#        [-0.25525636, -1.02564519, -0.36151411, ..., -0.6627914 ,
#          0.39575004, -0.62325216],
#        ...,
#        [-0.68104569,  0.56980288, -1.41077348, ...,  0.76267072,
#          2.00058467,  0.78734164],
#        [ 0.06408564,  0.56980288,  1.16029307, ..., -1.23297625,
#         -0.80787594, -1.18748968],
#        [ 0.27698031,  0.56980288, -1.10590393, ..., -1.23297625,
#         -0.80787594, -1.18748968]])

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Logisitic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_train=lr.predict(X_train)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_train, y_pred_train)
# Out:
# array([[966,  22],
#        [126,  62]], dtype=int64)

# %%
from sklearn.metrics import classification_report,precision_score,recall_score,f1_score,precision_recall_fscore_support
print('Precision                                     : ',precision_score(y_train, y_pred_train))
print('Recall                                        : ',recall_score(y_train, y_pred_train))
print('F1-Score                                      : ',f1_score(y_train, y_pred_train))
print('\nPrecision Recall F1-Score Support Per Class : \n',precision_recall_fscore_support(y_train, y_pred_train))
# Out:
# Precision                                     :  0.7380952380952381
# Recall                                        :  0.32978723404255317
# F1-Score                                      :  0.45588235294117646
#
# Precision Recall F1-Score Support Per Class :
#  (array([0.88461538, 0.73809524]), array([0.97773279, 0.32978723]), array([0.92884615, 0.45588235]), array([988, 188], dtype=int64))

# %%
print('\nClassification Report : ')
print(classification_report(y_train, y_pred_train))
# Out:
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       988
#            1       0.74      0.33      0.46       188
#
#     accuracy                           0.87      1176
#    macro avg       0.81      0.65      0.69      1176
# weighted avg       0.86      0.87      0.85      1176

# %%
y_pred_test=lr.predict(X_test)

# %%
confusion_matrix(y_test, y_pred_test)
# Out:
# array([[242,   3],
#        [ 31,  18]], dtype=int64)

# %%
print('Precision                                     : ',precision_score(y_test, y_pred_test))
print('Recall                                        : ',recall_score(y_test, y_pred_test))
print('F1-Score                                      : ',f1_score(y_test, y_pred_test))
print('\nPrecision Recall F1-Score Support Per Class : \n',precision_recall_fscore_support(y_test, y_pred_test))
# Out:
# Precision                                     :  0.8571428571428571
# Recall                                        :  0.3673469387755102
# F1-Score                                      :  0.5142857142857143
#
# Precision Recall F1-Score Support Per Class :
#  (array([0.88644689, 0.85714286]), array([0.9877551 , 0.36734694]), array([0.93436293, 0.51428571]), array([245,  49], dtype=int64))

# %%
print('\nClassification Report : ')
print(classification_report(y_test, y_pred_test))
# Out:
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.93       245
#            1       0.86      0.37      0.51        49
#
#     accuracy                           0.88       294
#    macro avg       0.87      0.68      0.72       294
# weighted avg       0.88      0.88      0.86       294

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
clf = DecisionTreeClassifier()

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_train=clf.predict(X_train)

# %%
confusion_matrix(y_train, y_pred_train)
# Out:
# array([[988,   0],
#        [  0, 188]], dtype=int64)

# %%
print('Precision                                     : ',precision_score(y_train, y_pred_train))
print('Recall                                        : ',recall_score(y_train, y_pred_train))
print('F1-Score                                      : ',f1_score(y_train, y_pred_train))
print('\nPrecision Recall F1-Score Support Per Class : \n',precision_recall_fscore_support(y_train, y_pred_train))
# Out:
# Precision                                     :  1.0
# Recall                                        :  1.0
# F1-Score                                      :  1.0
#
# Precision Recall F1-Score Support Per Class :
#  (array([1., 1.]), array([1., 1.]), array([1., 1.]), array([988, 188], dtype=int64))

# %%
print('\nClassification Report : ')
print(classification_report(y_train, y_pred_train))
# Out:
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       988
#            1       1.00      1.00      1.00       188
#
#     accuracy                           1.00      1176
#    macro avg       1.00      1.00      1.00      1176
# weighted avg       1.00      1.00      1.00      1176

# %%
y_pred_test=clf.predict(X_test)

# %%
confusion_matrix(y_test, y_pred_test)
# Out:
# array([[208,  37],
#        [ 30,  19]], dtype=int64)

# %%
print('Precision                                     : ',precision_score(y_train, y_pred_train))
print('Recall                                        : ',recall_score(y_train, y_pred_train))
print('F1-Score                                      : ',f1_score(y_train, y_pred_train))
print('\nPrecision Recall F1-Score Support Per Class : \n',precision_recall_fscore_support(y_train, y_pred_train))
# Out:
# Precision                                     :  1.0
# Recall                                        :  1.0
# F1-Score                                      :  1.0
#
# Precision Recall F1-Score Support Per Class :
#  (array([1., 1.]), array([1., 1.]), array([1., 1.]), array([988, 188], dtype=int64))

# %%
print('\nClassification Report : ')
print(classification_report(y_train, y_pred_train))
# Out:
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       988
#            1       1.00      1.00      1.00       188
#
#     accuracy                           1.00      1176
#    macro avg       1.00      1.00      1.00      1176
# weighted avg       1.00      1.00      1.00      1176

# %%
fig = plt.figure(figsize=(75,25))
Xdf = df.drop(columns=["Attrition"],axis=1)
ydf = df["Attrition"]
_ = plot_tree(clf, 
              feature_names=Xdf.columns,
              filled=True,
              class_names=ydf.unique().astype(str),
              fontsize=10)

# %%
dfFeatures = pd.DataFrame({'Features':Xdf.columns.tolist(),'Importances':clf.feature_importances_})
dfFeatures.sort_values(by='Importances',ascending=False).head(30)
# Out:
#                     Features  Importances
# 15             MonthlyIncome     0.098057
# 23         TotalWorkingYears     0.094779
# 9                 HourlyRate     0.074242
# 4           DistanceFromHome     0.069526
# 2                  DailyRate     0.068077
# 14             MaritalStatus     0.055898
# 0                        Age     0.054711
# 18                  OverTime     0.047769
# 16               MonthlyRate     0.044673
# 25           WorkLifeBalance     0.040911
# 10            JobInvolvement     0.036045
# 29      YearsWithCurrManager     0.033942
# 12                   JobRole     0.032371
# 19         PercentSalaryHike     0.030199
# 7    EnvironmentSatisfaction     0.030008
# 6             EducationField     0.029041
# 28   YearsSinceLastPromotion     0.028048
# 13           JobSatisfaction     0.025176
# 21  RelationshipSatisfaction     0.023365
# 17        NumCompaniesWorked     0.020567
# 26            YearsAtCompany     0.018938
# ...

# %%
fig=plt.figure(figsize=(40,40))
plt.pie(dfFeatures.Importances, labels = dfFeatures.Features, autopct='%0.1f%%', textprops={'fontsize':18})
plt.title('Feature Importances', fontsize=60) 
plt.show()
